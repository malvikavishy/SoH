# %%
import cv2
import mediapipe as mp
from matplotlib import pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
img = cv2.imread('hand.png')

# %%
imgplot = plt.imshow(img)

# %%
mp_hands = mp.solutions.hands

# %%
mp_drawing = mp.solutions.drawing_utils

# %%
hands = mp_hands.Hands(static_image_mode=True,
                      max_num_hands=2,
                      min_detection_confidence=0.7)

# %%
image = cv2.flip(img,1)

# %%
results = hands.process(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))

# %%
print('Handedness: ', results.multi_handedness)
# Out:
# Handedness:  [classification {
#   index: 1
#   score: 0.999631404876709
#   label: "Right"
# }
# ]

# %%
annoted_image = image.copy()
for hand_landmarks in results.multi_hand_landmarks:
    mp_drawing.draw_landmarks(annoted_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
#imageshow = plt.imshow(cv2.cvtColor(annoted_image,cv2.COLOR_BGR2RGB))
#cv2.imshow("Image",cv2.flip(annoted_image,1))
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
filename = 'savedImage.jpg'
cv2.imwrite(filename,annoted_image)
print("After saving image:")
# Out:
# After saving image:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-2287c31611b1> in <module>
#       2 cv2.imwrite(filename,annoted_image)
#       3 print("After saving image:")
# ----> 4 print(os.listdir(directory))
#
# NameError: name 'os' is not defined
